# %% [markdown]
# # Moin

# %%
import matplotlib.pyplot as plt

plt.plot([8,2,3,5])
plt.show()

# %%
import numpy as np

x = range(0,20)
y = [ np.sin(a/3.0) for a in x ]
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(-10.0,10.0,num = 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()
